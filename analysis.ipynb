# %%
import pandas as pd
from main import *

# %%
players_df = pd.read_csv("data/highest_earning_players.csv")
teams_df = pd.read_csv("data/highest_earning_teams.csv")
regions_df = pd.read_csv("data/country-and-continent-codes-list.csv")

regions_df['Two_Letter_Country_Code'] = regions_df['Two_Letter_Country_Code'].str.lower()

# %%
plot_distribution(players_df, 'TotalUSDPrize', filter_outliers=True)

# %%
plot_CLT(players_df, 'TotalUSDPrize', filter_outliers=True)

# %%
plot_violinplot(teams_df, 'TotalUSDPrize', filter_outliers=True)

# %%
plot_merged_boxplot(
	df1=regions_df,
	df2=players_df,
	x='TotalUSDPrize',
	y='Continent_Name',
	merge_col1='Two_Letter_Country_Code',
	merge_col2='CountryCode',
	hue="Genre",
	filter_outliers=False
)

# %%
plot_boxplot(df=players_df, x='TotalUSDPrize', y='Genre', filter_outliers=True, title="Players TotalUSDPrize by Genre")

# %%
plot_boxplot(df=teams_df, x='TotalUSDPrize', y='Genre', filter_outliers=True, title="Teams TotalUSDPrize by Genre")

# %%
plot_boxplot(df=players_df, x='TotalUSDPrize', y='Game', filter_outliers=True, title="Players TotalUSDPrize by Game")
